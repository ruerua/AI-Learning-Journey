# %%
import numpy as np
array = np.array([[1,2,3],
                  [2,3,4]])
print(array)
print('number of dim:', array.ndim)
print('shape:', array.shape)
print('size:', array.size)
# Out:
# [[1 2 3]
#  [2 3 4]]
# number of dim: 2
# shape: (2, 3)
# size: 6

# %% [markdown]
# ### 今日总结
#
# 今天学会了：
#
# - `np.array()` 创建数组
# - `np.zeros()` 创建全零矩阵
# - `np.random.randn()` 创建随机数组
#
# #### 小技巧
# - 用 `np.random.seed(42)` 固定随机结果
