# %%
import numpy as np
array = np.array([[1,2,3],
                  [2,3,4]])
print(array)
print('number of dim:', array.ndim)
print('shape:', array.shape)
print('size:', array.size)
# Out:
# [[1 2 3]
#  [2 3 4]]
# number of dim: 2
# shape: (2, 3)
# size: 6

# %% [markdown]
# ndim 几维
#
# shape 矩阵大小 m*n
#
# size 元素个数
